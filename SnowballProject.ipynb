# %% [markdown]
# # CREDIT TO JEFF SACKMANN FOR THE DATASET

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# data = pd.read_csv('pbp_matches_atp_qual_current.csv').set_index('pbp_id')
data = pd.read_csv('pbp_matches_atp_qual_current.csv').drop(columns=['Unnamed: 0', 'pbp_id'])
data
# Out:
#           date                                     tny_name tour  draw  \
# 0    01 Jan 17             ATPAucklandQualifying-ASBClassic  ATP  Qual
# 1    01 Jan 17  ATPBrisbaneQualifying-BrisbaneInternational  ATP  Qual
# 2    01 Jan 17  ATPBrisbaneQualifying-BrisbaneInternational  ATP  Qual
# 3    01 Jan 17  ATPBrisbaneQualifying-BrisbaneInternational  ATP  Qual
# 4    01 Jan 17  ATPBrisbaneQualifying-BrisbaneInternational  ATP  Qual
# ..         ...                                          ...  ...   ...
# 935  23 Aug 17                        Men'sUSOpenQualifying  ATP  Qual
# 936  23 Aug 17                        Men'sUSOpenQualifying  ATP  Qual
# 937  23 Aug 17                        Men'sUSOpenQualifying  ATP  Qual
# 938  23 Aug 17                        Men'sUSOpenQualifying  ATP  Qual
# 939  23 Aug 17                        Men'sUSOpenQualifying  ATP  Qual
#
#                 server1              server2  winner  \
# 0      Marcin Matkowski        Ryan Harrison       2
# ...

# %%
# Drop Wimbledon Final Qualifiers because they are played to best of 5 instead of best of 3
drop_list = data[data['tny_name'] == "Gentlemen'sWimbledonSinglesFinalRoundQualifying"].index
data.drop(drop_list, inplace=True)
data
# Out:
#           date                                     tny_name tour  draw  \
# 0    01 Jan 17             ATPAucklandQualifying-ASBClassic  ATP  Qual
# 1    01 Jan 17  ATPBrisbaneQualifying-BrisbaneInternational  ATP  Qual
# 2    01 Jan 17  ATPBrisbaneQualifying-BrisbaneInternational  ATP  Qual
# 3    01 Jan 17  ATPBrisbaneQualifying-BrisbaneInternational  ATP  Qual
# 4    01 Jan 17  ATPBrisbaneQualifying-BrisbaneInternational  ATP  Qual
# ..         ...                                          ...  ...   ...
# 935  23 Aug 17                        Men'sUSOpenQualifying  ATP  Qual
# 936  23 Aug 17                        Men'sUSOpenQualifying  ATP  Qual
# 937  23 Aug 17                        Men'sUSOpenQualifying  ATP  Qual
# 938  23 Aug 17                        Men'sUSOpenQualifying  ATP  Qual
# 939  23 Aug 17                        Men'sUSOpenQualifying  ATP  Qual
#
#                 server1              server2  winner  \
# 0      Marcin Matkowski        Ryan Harrison       2
# ...

# %%
fs_pbp = []
fs_game_count = []

# iterate through each match
for i in data.index:
    # extract pbp String
    match = data['pbp'][i]
    # extract first set
    first_set = match.split('.')[0]
    # record first set pbp
    fs_pbp.append(first_set)
    # record number of games in first set
    fs_game_count.append(first_set.count(';')+1)
    
data['fs_pbp'] = fs_pbp
data['num_fs_games'] = fs_game_count

data.head()
# Out:
#         date                                     tny_name tour  draw  \
# 0  01 Jan 17             ATPAucklandQualifying-ASBClassic  ATP  Qual
# 1  01 Jan 17  ATPBrisbaneQualifying-BrisbaneInternational  ATP  Qual
# 2  01 Jan 17  ATPBrisbaneQualifying-BrisbaneInternational  ATP  Qual
# 3  01 Jan 17  ATPBrisbaneQualifying-BrisbaneInternational  ATP  Qual
# 4  01 Jan 17  ATPBrisbaneQualifying-BrisbaneInternational  ATP  Qual
#
#               server1          server2  winner  \
# 0    Marcin Matkowski    Ryan Harrison       2
# 1      Alex De Minaur   Frances Tiafoe       1
# 2  Yoshihito Nishioka      Tim Smyczek       1
# 3    Ernesto Escobedo       Ivan Dodig       1
# 4  John-Patrick Smith  Jared Donaldson       2
#
#                                                  pbp           score  \
# 0  SDRSRD;SSSRS;SDSSRRSS;SSSRS;SDRDSASS;SSSS;ASRR...         6-4 6-4
# 1  SSSS;RRSRSSRSSA;SRSSRDSS;SSRSS;SSRRSS;SRASS;RS...  6-7(4) 6-4 6-4
# ...

# %%
print(data['fs_pbp'][1])
print(data.loc[1, 'fs_pbp'].split(';'))
# Out:
# SSSS;RRSRSSRSSA;SRSSRDSS;SSRSS;SSRRSS;SRASS;RSRSSRSRSRRR;RSRDR;SSSS;ASSRS;SSRSDS;RRSSSS;S/SS/SS/SA/AD/SA
# ['SSSS', 'RRSRSSRSSA', 'SRSSRDSS', 'SSRSS', 'SSRRSS', 'SRASS', 'RSRSSRSRSRRR', 'RSRDR', 'SSSS', 'ASSRS', 'SSRSDS', 'RRSSSS', 'S/SS/SS/SA/AD/SA']

# %%
data
# Out:
#           date                                     tny_name tour  draw  \
# 0    01 Jan 17             ATPAucklandQualifying-ASBClassic  ATP  Qual
# 1    01 Jan 17  ATPBrisbaneQualifying-BrisbaneInternational  ATP  Qual
# 2    01 Jan 17  ATPBrisbaneQualifying-BrisbaneInternational  ATP  Qual
# 3    01 Jan 17  ATPBrisbaneQualifying-BrisbaneInternational  ATP  Qual
# 4    01 Jan 17  ATPBrisbaneQualifying-BrisbaneInternational  ATP  Qual
# ..         ...                                          ...  ...   ...
# 935  23 Aug 17                        Men'sUSOpenQualifying  ATP  Qual
# 936  23 Aug 17                        Men'sUSOpenQualifying  ATP  Qual
# 937  23 Aug 17                        Men'sUSOpenQualifying  ATP  Qual
# 938  23 Aug 17                        Men'sUSOpenQualifying  ATP  Qual
# 939  23 Aug 17                        Men'sUSOpenQualifying  ATP  Qual
#
#                 server1              server2  winner  \
# 0      Marcin Matkowski        Ryan Harrison       2
# ...

# %%
### FUNCTIONS TO EXTRACT INFORMATION ###

# Function to extract relevant data from a game pbp string
def extract_game_data(game_pbp):
    
    s_points = 0
    r_points = 0
    s_momentum = 0
    r_momentum = 0
    breaks = 0
    aces = 0
    
    # iterate through each point
    for i in range(len(game_pbp)):
        point = game_pbp[i]
        
        # Handle momentum quantification
        serve_momentum, m_count = momentum_check(game_pbp[i:])
        if m_count > 0:
            if serve_momentum:
                s_momentum+=1
            else:
                r_momentum+=1
        
        if point == 'S':
            s_points+=1
        elif point == 'A':
            aces+=1
            s_points+=1
        elif point == 'R':
            r_points+=1
        elif point == 'D':
            r_points+=1
        else:
            s_points+=0
            
    if r_points > s_points:
        breaks = 1
            
    return [s_points, r_points, s_momentum, r_momentum, breaks, aces]


# Function to extract relevant data from a tiebreak
def extract_tiebreak_data(tiebreak_pbp):
    
    p1_points = 0
    p2_points = 0
    p1_momentum = 0
    p2_momentum = 0
    p1_aces = 0
    p2_aces = 0
    
    p1_serving = False
    
    splits = str(tiebreak_pbp).split('/')
    
    # iterate through each point
    for points in splits:
        # toggle boolean flag
        p1_serving = not p1_serving
        
        s_points = 0
        r_points = 0
        s_momentum = 0
        r_momentum = 0
        aces = 0
        
        # Handle momentum quantification
        serve_momentum, m_count = momentum_check(points, tiebreak=True)
        if m_count > 0:
            if serve_momentum:
                s_momentum+=1
            else:
                r_momentum+=1
        
        for point in points:
                
            if point == 'S':
                s_points+=1
            elif point == 'A':
                aces+=1
                s_points+=1
            elif point == 'R':
                r_points+=1
            elif point == 'D':
                r_points+=1
            else:
                s_points+=0
            
        if p1_serving:
            p1_points+=s_points
            p2_points+=r_points
            p1_momentum+=s_momentum
            p2_momentum+=r_momentum
            p1_aces+=aces
        else:
            p2_points+=s_points
            p1_points+=r_points
            p2_momentum+=s_momentum
            p1_momentum+=r_momentum
            p2_aces+=aces
            
    return [p1_points, p2_points, p1_momentum, p2_momentum, p1_aces, p2_aces]


def momentum_check(pbp, tiebreak=False):
    momentum_threshold = 3
    if tiebreak:
        momentum_threshold = 2
    
    s_momentum = True
    momentum = 0
    if len(pbp) >= momentum_threshold:
        if set(pbp[:momentum_threshold]).issubset({'A', 'S'}):
            momentum+=1
        if set(pbp[:momentum_threshold]).issubset({'R', 'D'}):
            momentum+=1
            s_momentum = False
    return s_momentum, momentum


def is_p1_set_winner(last_game_pbp, num_games):

    # If tiebreak decider
    if num_games > 12:
        p1_points = 0
        p2_points = 0

        switches = last_game_pbp.split('/')
        p1_serves = switches[::2]
        p2_serves = switches[1::2]
        for switch in p1_serves:
            p1_points += switch.count('A')
            p1_points += switch.count('S')
            p2_points += switch.count('R')
            p2_points += switch.count('D')
        for switch in p2_serves:
            p2_points += switch.count('A')
            p2_points += switch.count('S')
            p1_points += switch.count('R')
            p1_points += switch.count('D')
        return p1_points > p2_points
    else:
        s_points = 0
        r_points = 0

        s_points += last_game_pbp.count('A')
        s_points += last_game_pbp.count('S')
        r_points += last_game_pbp.count('R')
        r_points += last_game_pbp.count('D')

        # If p2 serves
        if num_games % 2 == 0:
            return r_points > s_points
        # If p1 serves
        else:
            return s_points > r_points

# %%
fs_s1_points = []
fs_s2_points = []
fs_s1_momentum = []
fs_s2_momentum = []
fs_s1_breaks = []
fs_s2_breaks = []
fs_s1_aces = []
fs_s2_aces = []
p1_win = []
p1_win_first_set = []

# Iterate through each match(row)
for i in data.index:
    # create list of games in the match
    games = data.loc[i,'fs_pbp'].split(';')
    
    # Split games into those served by p1 and p2
    p1_s_games = games[::2]
    p2_s_games = games[1::2]
    tiebreak = []
    
    # If there is a tiebreak
    if(len(p1_s_games)==7):
        tiebreak = p1_s_games.pop(6)
        
    fs_s1_points_count = 0
    fs_s2_points_count = 0
    fs_s1_momentum_count = 0
    fs_s2_momentum_count = 0
    fs_s1_breaks_count = 0
    fs_s2_breaks_count = 0
    fs_s1_aces_count = 0
    fs_s2_aces_count = 0
    
    # Aggregate data from p1 serving games
    for game in p1_s_games:
        game_data = extract_game_data(game)
        fs_s1_points_count+=game_data[0]
        fs_s2_points_count+=game_data[1]
        fs_s1_momentum_count+=game_data[2]
        fs_s2_momentum_count+=game_data[3]
        fs_s2_breaks_count+=game_data[4]
        fs_s1_aces_count+=game_data[5]
        
    # Aggregate data from p2 serving games
    for game in p2_s_games:
        game_data = extract_game_data(game)
        fs_s2_points_count+=game_data[0]
        fs_s1_points_count+=game_data[1]
        fs_s2_momentum_count+=game_data[2]
        fs_s1_momentum_count+=game_data[3]
        fs_s1_breaks_count+=game_data[4]
        fs_s2_aces_count+=game_data[5]
        
    # Aggregate data from tiebreak
    tb_data = extract_tiebreak_data(tiebreak)
    fs_s1_points_count+=tb_data[0]
    fs_s2_points_count+=tb_data[1]
    fs_s1_momentum_count+=tb_data[2]
    fs_s2_momentum_count+=tb_data[3]
    fs_s1_aces_count+=tb_data[4]
    fs_s2_aces_count+=tb_data[5]

    # Add the match's data to the lists
    fs_s1_points.append(fs_s1_points_count)
    fs_s2_points.append(fs_s2_points_count)
    fs_s1_momentum.append(fs_s1_momentum_count)
    fs_s2_momentum.append(fs_s2_momentum_count)
    fs_s1_breaks.append(fs_s1_breaks_count)
    fs_s2_breaks.append(fs_s2_breaks_count)
    fs_s1_aces.append(fs_s1_aces_count)
    fs_s2_aces.append(fs_s2_aces_count)

    p1_win.append(data.loc[i, 'winner'] == 1)
    
    p1_win_first_set.append(is_p1_set_winner(games[-1], len(games)))
    
    
data['fs_s1_points'] = fs_s1_points
data['fs_s2_points'] = fs_s2_points
data['fs_s1_momentum'] = fs_s1_momentum
data['fs_s2_momentum'] = fs_s2_momentum
data['fs_s1_breaks'] = fs_s1_breaks
data['fs_s2_breaks'] = fs_s2_breaks
data['fs_s1_aces'] = fs_s1_aces
data['fs_s2_aces'] = fs_s2_aces
data['p1_win'] = p1_win 
data['p1_win_fs'] = p1_win_first_set
    
data
    
#     if(i==1):
# #         print(p1_s_games)
# #         print(p2_s_games)
# #         print(tiebreak)
# #         a = tiebreak.split('/')
# #         for b in a:
# #             print(b, end='\n')
#         print(game_data)
#         print(tb_data)
# #         print(tiebreak.split('/'))
# Out:
#           date                                     tny_name tour  draw  \
# 0    01 Jan 17             ATPAucklandQualifying-ASBClassic  ATP  Qual
# 1    01 Jan 17  ATPBrisbaneQualifying-BrisbaneInternational  ATP  Qual
# 2    01 Jan 17  ATPBrisbaneQualifying-BrisbaneInternational  ATP  Qual
# 3    01 Jan 17  ATPBrisbaneQualifying-BrisbaneInternational  ATP  Qual
# 4    01 Jan 17  ATPBrisbaneQualifying-BrisbaneInternational  ATP  Qual
# ..         ...                                          ...  ...   ...
# 935  23 Aug 17                        Men'sUSOpenQualifying  ATP  Qual
# 936  23 Aug 17                        Men'sUSOpenQualifying  ATP  Qual
# 937  23 Aug 17                        Men'sUSOpenQualifying  ATP  Qual
# 938  23 Aug 17                        Men'sUSOpenQualifying  ATP  Qual
# 939  23 Aug 17                        Men'sUSOpenQualifying  ATP  Qual
#
#                 server1              server2  winner  \
# 0      Marcin Matkowski        Ryan Harrison       2
# ...

# %%
# EXPECTED RESULTS FOR ROW INDEX 1 STATS

# ['SSSS', 'RRSRSSRSSA', 'SRSSRDSS', 'SSRSS', 'SSRRSS', 'SRASS']
# ['RSRSSRSRSRRR', 'RSRDR', 'SSSS', 'ASSRS', 'SSRSDS', 'RRSSSS']
# ['S/SS/SS/SA/AD/SA']


# s1_points = 39+4=43
# s2 points = 37+7=44
# s1 momentum =
# s2 momentum =
# s1 breaks =
# s2 breaks =
# s1 aces =
# s2 aces =

# %%
momentum_check('RD', True)
# Out:
# (False, 1)

# %%
# Works as expected
extract_game_data('AASRRDADRDR')
# Out:
# [4, 7, 1, 3, 1, 3]

# %%
extract_tiebreak_data('S/SS/SS/SA/AD/SA')
# Out:
# [4, 7, 1, 3, 1, 2]

# %%
# percent_s1_points = []
# percent_s1_momentum = []
# percent_s1_breaks = []
# percent_s1_aces = []

# for match_id in data.index:
#     s1_points = data['fs_s1_points'][match_id]
#     s2_points = data['fs_s2_points'][match_id]
#     percent_s1_points.append(s1_points/(s1_points+s2_points))
    
#     s1_m = data['fs_s1_momentum'][match_id]
#     s2_m = data['fs_s2_momentum'][match_id]
#     percent_s1_momentum.append(s1_m/(s1_m+s2_m))
    
#     s1_b = data['fs_s1_breaks'][match_id]
#     s2_b = data['fs_s2_breaks'][match_id]
#     percent_s1_breaks.append(s1_b/(s1_b+s2_b))
    
#     s1_a = data['fs_s1_aces'][match_id]
#     s2_a = data['fs_s2_aces'][match_id]
#     percent_s1_aces.append(s1_a/(s1_a+s2_a))
    
# data['percent_s1_points'] = percent_s1_points    
# data['percent_s1_momentum'] = percent_s1_momentum    
# data['percent_s1_breaks'] = percent_s1_breaks   
# data['percent_s1_aces'] = percent_s1_aces



# label encoding for features

# 1 if p1 win, 0 if p2 win
data['p1_win'] = data['p1_win'].map({True: 1, False: 0})
# 1 if p1 win, 0 if p2 win
data['p1_win_fs'] = data['p1_win_fs'].map({True: 1, False: 0})

# %%
data
# Out:
#           date                                     tny_name tour  draw  \
# 0    01 Jan 17             ATPAucklandQualifying-ASBClassic  ATP  Qual
# 1    01 Jan 17  ATPBrisbaneQualifying-BrisbaneInternational  ATP  Qual
# 2    01 Jan 17  ATPBrisbaneQualifying-BrisbaneInternational  ATP  Qual
# 3    01 Jan 17  ATPBrisbaneQualifying-BrisbaneInternational  ATP  Qual
# 4    01 Jan 17  ATPBrisbaneQualifying-BrisbaneInternational  ATP  Qual
# ..         ...                                          ...  ...   ...
# 935  23 Aug 17                        Men'sUSOpenQualifying  ATP  Qual
# 936  23 Aug 17                        Men'sUSOpenQualifying  ATP  Qual
# 937  23 Aug 17                        Men'sUSOpenQualifying  ATP  Qual
# 938  23 Aug 17                        Men'sUSOpenQualifying  ATP  Qual
# 939  23 Aug 17                        Men'sUSOpenQualifying  ATP  Qual
#
#                 server1              server2  winner  \
# 0      Marcin Matkowski        Ryan Harrison       2
# ...

# %%
data = data.fillna(0)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV #we will do hyperparameters tuning

# %%
missing_index = np.array(data.isnull()).nonzero()[0] #indices of missing values
missing_index
# Out:
# array([], dtype=int64)

# %%
y = data.p1_win

# relevant_columns = ['fs_s1_momentum', 'fs_s2_momentum', 
#                     'fs_s1_breaks', 'fs_s2_breaks', 'fs_s1_aces', 'fs_s2_aces', 'percent_s1_points']

# relevant_columns = ['fs_s1_momentum', 'fs_s2_momentum', 
#                     'fs_s1_breaks', 'fs_s2_breaks', 'fs_s1_aces', 'fs_s2_aces', 'fs_s1_points', 'fs_s2_points']

relevant_columns = ['fs_s1_momentum', 'fs_s2_momentum', 
                    'fs_s1_breaks', 'fs_s2_breaks', 'fs_s1_aces', 'fs_s2_aces', 'fs_s1_points',
                    'fs_s2_points', 'p1_win_fs']

# relevant_columns = ['percent_s1_points', 'percent_s1_momentum', 'percent_s1_breaks', 'percent_s1_aces']

X = data[relevant_columns]

# %%
#we scale numeric features because they have different magnitudes which can impact the performance of our model

feature_names = X.columns

import scipy.stats as stats
X = X.apply(stats.zscore)
X
# Out:
#      fs_s1_momentum  fs_s2_momentum  fs_s1_breaks  fs_s2_breaks  fs_s1_aces  \
# 0         -0.927955        1.201773     -1.127870     -0.145079    0.575466
# 1          0.159492        1.201773     -0.104043     -0.145079   -0.511982
# 2         -1.290438        1.541932      0.919784     -0.145079   -1.055707
# 3         -0.565473       -1.179341     -0.104043     -1.131831   -0.511982
# 4         -0.927955       -0.839182     -1.127870      0.841673   -1.055707
# ..              ...             ...           ...           ...         ...
# 935       -1.652920       -0.158864     -0.104043      1.828425    0.031742
# 936       -0.565473        2.222251     -1.127870     -0.145079   -0.511982
# 937        0.521975        1.541932     -0.104043      0.841673    0.031742
# 938       -0.202990       -0.839182      0.919784     -0.145079    0.575466
# 939        1.971905        0.861614     -1.127870     -1.131831   -0.511982
#
#      fs_s2_aces  fs_s1_points  fs_s2_points  p1_win_fs
# ...

# %%
# l = len(X)
# split = int(l*0.7) 
# X_train, X_test = X[:split], X[split:]
# y_train, y_test = y[:split], y[split:]

# #We convert the pandas dataframes into numpy matrices
# X_train, X_test = np.array(X_train), np.array(X_test)
# y_train, y_test = np.array(y_train), np.array(y_test)

# %%
# %%time
# logit = LogisticRegression(random_state=75, solver='liblinear') #We set a random state so that the results are reproducible
# logit.fit(X_train, y_train) #We train the model
# y_logit_pred = logit.predict_proba(X_test) #We make predictions
# Out:
# CPU times: user 3.92 ms, sys: 3.33 ms, total: 7.25 ms
# Wall time: 12.4 ms

# %%
logit_score = roc_auc_score(y_true=y_test,y_score=y_logit_pred[:,1])
print('Logistic Regression score : {}'.format(logit_score))
# Out:
# Logistic Regression score : 0.8293207448203513

# %%
import scipy.stats as stats

def features_and_target(df):
    features = df.iloc[:,:len(df.columns)-1]
    target = df.iloc[:,len(df.columns)-1]
    return features, target

# %%
rel_columns = ['fs_s1_momentum', 'fs_s2_momentum', 
               'fs_s1_breaks', 'fs_s2_breaks', 'fs_s1_aces',
               'fs_s2_aces', 'fs_s1_points', 'fs_s2_points', 'p1_win_fs', 'p1_win']


ml_data = data[rel_columns]

features, target = features_and_target(ml_data)

# %%
features
# Out:
#      fs_s1_momentum  fs_s2_momentum  fs_s1_breaks  fs_s2_breaks  fs_s1_aces  \
# 0                 3               9             0             1           3
# 1                 6               9             1             1           1
# 2                 2              10             2             1           0
# 3                 4               2             1             0           1
# 4                 3               3             0             2           0
# ..              ...             ...           ...           ...         ...
# 935               1               5             1             3           2
# 936               4              12             0             1           1
# 937               7              10             1             2           2
# 938               5               3             2             1           3
# 939              11               8             0             0           1
#
#      fs_s2_aces  fs_s1_points  fs_s2_points  p1_win_fs
# ...

# %%
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 935    0
# 936    0
# 937    1
# 938    1
# 939    1
# Name: p1_win, Length: 925, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler

#split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, random_state=3000)

#create the scaler
scaler = MinMaxScaler()

#fit the scaler to the training data(features only)
scaler.fit(X_train) 

#transform X_train and X_test based on the (same) scaler
X_train_scaled = scaler.transform(X_train) 
X_test_scaled = scaler.transform(X_test) 

#create the model by fitting the training data
logit = LogisticRegression(random_state=75, solver='liblinear')

logit.fit(X_train_scaled, y_train) #We train the model
# y_logit_pred = logit.predict_proba(X_test) #We make predictions

#make predictions on the test set
predicted = logit.predict(X=X_test_scaled)

#prediction accuracy
accuracy = logit.score(X_test_scaled, y_test)
print("Prediction accuracy on the test data:", format(accuracy*100, ".2f"))

logit_score = roc_auc_score(y_true=y_test,y_score=predicted)
print('Logistic Regression score : {}'.format(logit_score))
# Out:
# Prediction accuracy on the test data: 82.76
# Logistic Regression score : 0.8330338424678048

# %%
# Export model

import pickle
pickle.dump(logit, open('tennis_prediction_model.pk1', 'wb'))

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler

#split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, random_state=3000)

#create the scaler
scaler = MinMaxScaler()

#fit the scaler to the training data(features only)
scaler.fit(X_train) 

#transform X_train and X_test based on the (same) scaler
X_train_scaled = scaler.transform(X_train) 
X_test_scaled = scaler.transform(X_test) 

#select a classifier
knn = KNeighborsClassifier(n_neighbors=17)

#create the model by fitting the training data
knn.fit(X=X_train_scaled, y=y_train)

#make predictions on the test set
predicted = knn.predict(X=X_test_scaled)

#prediction accuracy
accuracy = knn.score(X_test_scaled, y_test)
print("Prediction accuracy on the test data:", format(accuracy*100, ".2f"))
# Out:
# Prediction accuracy on the test data: 82.76

# %%
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

estimators = {
    'Logistic Regression': LogisticRegression(solver='liblinear'),
    'k-Nearest Neighbor': KNeighborsClassifier(n_neighbors=17), 
    'Support Vector Machine': LinearSVC(max_iter=1000000),
    'Gaussian Naive Bayes': GaussianNB(),
    'Decision Tree': DecisionTreeClassifier(),
    'Second Decision Tree': DecisionTreeClassifier(max_depth=3)}

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

def classifiers_percentage_split():
    
    features, target = features_and_target(ml_data)
    
    # Split the dataset into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(features, target, random_state=3000)
    
    #create the scaler
    scaler = MinMaxScaler()

    #fit the scaler to the training data(features only)
    scaler.fit(X_train) 

    #transform X_train and X_test based on the (same) scaler
    X_train_scaled = scaler.transform(X_train) 
    X_test_scaled = scaler.transform(X_test) 

    for estimator_name, estimator_object in estimators.items():

        # Create the model by fitting the training data
        model = estimator_object.fit(X=X_train_scaled, y=y_train)

        # Make predictions on the test set
        predicted = model.predict(X=X_test_scaled)

        # Prediction accuracy
        accuracy = model.score(X_test_scaled, y_test)
        
        print(estimator_name + ':\n\t' + f'Classification accuracy on the test data: {accuracy:.2%}\n')

# %%
classifiers_percentage_split()
# Out:
# Logistic Regression:
# 	Classification accuracy on the test data: 82.76%
#
# k-Nearest Neighbor:
# 	Classification accuracy on the test data: 82.76%
#
# Support Vector Machine:
# 	Classification accuracy on the test data: 82.76%
#
# Gaussian Naive Bayes:
# 	Classification accuracy on the test data: 82.76%
#
# Decision Tree:
# 	Classification accuracy on the test data: 67.24%
#
# Second Decision Tree:
# 	Classification accuracy on the test data: 82.76%

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

def classifiers_cross_validation():
    
    for estimator_name, estimator_object in estimators.items():
        kfold = KFold(n_splits=10, random_state=3000, shuffle=True)
    
        scores = cross_val_score(estimator=estimator_object, X=features, y=target, cv=kfold)
    
        print(estimator_name + ": \n\t" + f'mean accuracy={scores.mean():.2%}, '
          + f'standard deviation={scores.std():.2%}' +"\n")

# %%
classifiers_cross_validation()
# Out:
# Logistic Regression:
# 	mean accuracy=80.42%, standard deviation=4.25%
#
# k-Nearest Neighbor:
# 	mean accuracy=77.72%, standard deviation=5.59%
#
# Support Vector Machine:
# 	mean accuracy=80.42%, standard deviation=4.25%
#
# Gaussian Naive Bayes:
# 	mean accuracy=80.10%, standard deviation=4.65%
#
# Decision Tree:
# 	mean accuracy=67.68%, standard deviation=5.19%
#
# Second Decision Tree:
# 	mean accuracy=80.10%, standard deviation=4.36%

# %%
matches = 0
for i in data.index:
    if data['p1_win'][i]==data['p1_win_fs'][i]:
        matches+=1
matches/len(data)

# Only using first set winner results in 80.43% prediction accuracy
# Out:
# 0.8043243243243243
